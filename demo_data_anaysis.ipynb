# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import DataAnalyzer

# %% [markdown]
# # Data Analyzer

# %%
print(DataAnalyzer.__doc__)
# Out:
# A data analyzer for Driver Monitoring System Initialize the basic data to be loaded.
#     Args:
#         drivers: `list` or `tuple`, the registered name of meta data.
#         Loads data only for passed driver(s).
#
#         states: `list` or `tuple`, the predefined driver's states.
#         Loads data only for passed state(s).
#         Reference: "Multimodal data collection system for driver emotion recognition based on self-reporting in real-world driving." Oh, Geesung, et al., 2022, Sensors.
#
#         name: `str`, the name of the data analyzer.
#
#     ```python
#     from utils import DataAnalyzer
#
#     data_analyzer = DataAnalyzer()
#     ```

# %% [markdown]
# ## Initialize

# %%
drivers = [
    'GeesungOh',
    'EuiseokJeong',
    'TaesanKim',
]

states = [
    # 'Unknown',
    'Angry/Disgusting',
    'Excited/Surprised',
    'Sad/Fatigued',
    'Happy/Neutral',
]

data_analyzer = DataAnalyzer(drivers=drivers,
                         states=states,
                         name='total_data'
                         )

# %%
print(data_analyzer.drivers)
print(data_analyzer.states)
print(data_analyzer.name)
# Out:
# ['GeesungOh', 'EuiseokJeong', 'TaesanKim']
# [1, 2, 3, 4]
# total_data

# %% [markdown]
# ## Categorical distribution of HMI

# %%
print(data_analyzer.plot_HMI_count.__doc__)

# %%
df_HMI_count = data_analyzer.plot_HMI_count(byDriver=False)
# df_HMI_count = data_analyzer.plot_HMI_count(byDriver=True)

# %%
df_HMI_count

# %% [markdown]
# ## Mean value distribution by each HMI

# %%
print(data_analyzer.plot_mean_value.__doc__)

# %%
from config import cols_BIO

col = cols_BIO[0]
print(col)
# prev_sec = 1000
prev_sec = 1
data_analyzer.plot_mean_value(col, 
                            prev_sec=prev_sec, 
                            byDriver=False)
data_analyzer.plot_mean_value(col, 
                            prev_sec=prev_sec, 
                            byDriver=True)

# %%
from config import cols_CAN_conti

col = cols_CAN_conti[5]
print(col)
prev_sec = 100

# data_analyzer.plot_mean_value(col, 
                            # prev_sec=prev_sec, 
                            # byDriver=False)
data_analyzer.plot_mean_value(col, 
                            prev_sec=prev_sec, 
                            byDriver=True)

# %% [markdown]
# ## Mean Image by each HMI

# %%
print(data_analyzer.show_mean_image.__doc__)

# %%
mean_img, show_dict = data_analyzer.show_mean_image(view='front', # front or side
                                                    mode='color',  # color or ir
                                                    prev_sec=2,
                                                    byDriver=True,
                                                    # showEach=True,
                                                    )

# mean_img, show_dict = data_analyzer.show_mean_image_draft(
                                                    # byDriver=True,
                                                    # mean_img=mean_img)
# Out:
# Driver:  GeesungOh
# State:  Angry/Disgusting
# Number of raw images:  270
# Mean image shape:  (720, 1280, 3)
# Driver:  EuiseokJeong
# State:  Angry/Disgusting
# Number of raw images:  210
# Mean image shape:  (720, 1280, 3)
# Driver:  TaesanKim
# State:  Angry/Disgusting
# Number of raw images:  210
# Mean image shape:  (720, 1280, 3)
# Driver:  GeesungOh
# State:  Excited/Surprised
# Number of raw images:  271
# Mean image shape:  (720, 1280, 3)
# Driver:  EuiseokJeong
# State:  Excited/Surprised
# Number of raw images:  330
# Mean image shape:  (720, 1280, 3)
# Driver:  TaesanKim
# State:  Excited/Surprised
# Number of raw images:  390
# Mean image shape:  (720, 1280, 3)
# Driver:  GeesungOh
# State:  Sad/Fatigued
# Number of raw images:  2340
# Mean image shape:  (720, 1280, 3)
# Driver:  EuiseokJeong
# State:  Sad/Fatigued
# Number of raw images:  269
# Mean image shape:  (720, 1280, 3)
# Driver:  TaesanKim
# State:  Sad/Fatigued
# Number of raw images:  990
# Mean image shape:  (720, 1280, 3)
# Driver:  GeesungOh
# State:  Happy/Neutral
# Number of raw images:  4676
# Mean image shape:  (720, 1280, 3)
# Driver:  EuiseokJeong
# State:  Happy/Neutral
# Number of raw images:  7437
# Mean image shape:  (720, 1280, 3)
# Driver:  TaesanKim
# State:  Happy/Neutral
# Number of raw images:  5524
# Mean image shape:  (720, 1280, 3)
